# %% [markdown]
# ### TPC4: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um elemento na lista, se o encontrar deverá devolver a sua posição, devolverá -1 se o elemento não estiver na lista;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
# 1
def cria_lista_aleatoria():
    import random
    n = 0
    while n < 5:
        numero_aleatorio = random.randint(1, 100)
        interna.append(numero_aleatorio)
        n = n + 1

#2
def leLista():
    n = 0
    while n < 5:
        interna.append(int(input("introduza um número inteiro")))
        n = n + 1

#3
def somaLista():
    res = 0 
    for n in interna:
        res = res + n 
    final.append(res)
    #soma += num é o mesmo que soma = soma + num

#4
def mediaLista():
   res = 0 
   c = 0
   for n in interna:
        res = res + n 
        c = c + 1
        média = res / c
   final.append(média)

#5
def maiorLista():
    res = 0
    for n in interna:
        if n > res:
            res = n
    final.append(res)

#6
def menorLista():
    res = interna[0] 
    for n in interna:
        if n < res:
            res = n
    final.append(res)

#7
def estaOrdenadaC():
    for n in  range(0, len(interna) - 1):
        if interna[n] < interna[n + 1]:
            n = n + 1
        else: 
            return "Não"
    return "Sim"
    
#8
def estaOrdenadaD():
    for n in  range(0, len(interna) - 1):
        if interna[n] > interna[n + 1]:
            n = n + 1
        else: 
            return "Não"
    return "Sim"

#9
def unicos():
    elemento = int(input("indique um elemento"))
    for str in interna:
        if str == elemento:    
            return  interna.index(elemento)
    return -1

#neste caso como se a escolha for 1 nunca vai ser outro numero podiamos por if com todos
escolha = -1
interna = []
final = []

while escolha != 0:
    escolha = int(input("escolha uma das opções introduzindo o número correspondente" + "* (1) Criar Lista" + "* (2) Ler Lista" + "* (3) Soma" + "* (4) Média" + "* (5) Maior" +
                        "* (6) Menor" + "* (7) estaOrdenada por ordem crescente" + "* (8) estaOrdenada por ordem decrescente" + "* (9) Procura um elemento" + "* (0) Sair  "))
    if escolha == 1:
        interna = []
        cria_lista_aleatoria()
        print (interna)
    elif escolha == 2:
        interna = []
        leLista()
        print (interna)
    elif escolha == 3:
        somaLista()
        print (final)
    elif escolha == 4:
        mediaLista()
        print (final)
    elif escolha == 5:
        maiorLista()
        print (final)
    elif escolha == 6:
        menorLista ()
        print (final)
    elif escolha == 7:
        print (estaOrdenadaC())
    elif escolha == 8:
        print (estaOrdenadaD())
    elif escolha == 9:
        print (unicos())

        

print (final)
# Out:
# [2, 97, 18, 43, 84]
# [2, 3, 4, 5, 6]
# [20]
# [20, 20]
# [20, 20, 4.0]
# [20, 20, 4.0, 6]
# [20, 20, 4.0, 6, 2]
# Sim
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\saraa\Documents\uni 2ºano\programação\TPC 4.ipynb Cell 2 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/saraa/Documents/uni%202%C2%BAano/programa%C3%A7%C3%A3o/TPC%204.ipynb#W1sZmlsZQ%3D%3D?line=79'>80</a> final = []
#      <a href='vscode-notebook-cell:/c%3A/Users/saraa/Documents/uni%202%C2%BAano/programa%C3%A7%C3%A3o/TPC%204.ipynb#W1sZmlsZQ%3D%3D?line=81'>82</a> while escolha != 0:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/saraa/Documents/uni%202%C2%BAano/programa%C3%A7%C3%A3o/TPC%204.ipynb#W1sZmlsZQ%3D%3D?line=82'>83</a>     escolha = int(input("escolha uma das opções introduzindo o número correspondente" + "* (1) Criar Lista" + "* (2) Ler Lista" + "* (3) Soma" + "* (4) Média" + "* (5) Maior" +
#      <a href='vscode-notebook-cell:/c%3A/Users/saraa/Documents/uni%202%C2%BAano/programa%C3%A7%C3%A3o/TPC%204.ipynb#W1sZmlsZQ%3D%3D?line=83'>84</a>                         "* (6) Menor" + "* (7) estaOrdenada por ordem crescente" + "* (8) estaOrdenada por ordem decrescente" + "* (9) Procura um elemento" + "* (0) Sair  "))
#      <a href='vscode-notebook-cell:/c%3A/Users/saraa/Documents/uni%202%C2%BAano/programa%C3%A7%C3%A3o/TPC%204.ipynb#W1sZmlsZQ%3D%3D?line=84'>85</a>     if escolha == 1:
#      <a href='vscode-notebook-cell:/c%3A/Users/saraa/Documents/uni%202%C2%BAano/programa%C3%A7%C3%A3o/TPC%204.ipynb#W1sZmlsZQ%3D%3D?line=85'>86</a>         interna = []
#
# ValueError: invalid literal for int() with base 10: ''
